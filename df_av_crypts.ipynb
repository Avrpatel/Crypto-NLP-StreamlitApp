# %%
import pandas as pd
from pathlib import Path

# %%
btc_march_df = Path('btc_march.csv')
btc_march = pd.read_csv(btc_march_df)
btc_march = btc_march.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])


btc_april_df = Path('btc_april.csv')
btc_april = pd.read_csv(btc_april_df)
btc_april = btc_april.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])



btc_may_df = Path('btc_may.csv')
btc_may = pd.read_csv(btc_may_df)
btc_may = btc_may.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])



btc_june_df = Path('btc_june.csv')
btc_june = pd.read_csv(btc_june_df)
btc_june = btc_june.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])



btc_july_df = Path('btc_july.csv')
btc_july = pd.read_csv(btc_july_df)
btc_july = btc_july.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

btc_sent = pd.concat([btc_march, btc_april, btc_may, btc_june, btc_july], axis=1, keys=["March_BTC", "April_BTC", "May_BTC", "June_BTC", "July_BTC"])
btc_sent.head()

# Read CSV files from List
#df = pd.concat(map(pd.read_csv, ['btc_march.csv', 'btc_april.csv','btc_may.csv','btc_june.csv','btc_july.csv']))
#df.head()

filepath = Path('btc_sent.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
btc_sent.to_csv(filepath)

# %%
eth_march_df = Path('eth_march.csv')
eth_march = pd.read_csv(eth_march_df)
eth_march = eth_march.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])


eth_april_df = Path('eth_april.csv')
eth_april = pd.read_csv(eth_april_df)
eth_april = eth_april.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])



eth_may_df = Path('eth_may.csv')
eth_may = pd.read_csv(eth_may_df)
eth_may = eth_may.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])


eth_june_df = Path('eth_june.csv')
eth_june = pd.read_csv(eth_june_df)
eth_june = eth_june.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])



eth_july_df = Path('eth_july.csv')
eth_july = pd.read_csv(eth_july_df)
eth_july = eth_july.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

eth_sent = pd.concat([eth_march, eth_april, eth_may, eth_june, eth_july], axis=1, keys=["March_ETH", "April_ETH", "May_ETH", "June_ETH", "July_ETH"])
eth_sent.head()

filepath = Path('eth_sent.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
eth_sent.to_csv(filepath)

# %%
ada_march_df = Path('ada_march.csv')
ada_march = pd.read_csv(ada_march_df)
ada_march = ada_march.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

ada_april_df = Path('ada_april.csv')
ada_april = pd.read_csv(ada_april_df)
ada_april = ada_april.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

ada_may_df = Path('ada_may.csv')
ada_may = pd.read_csv(ada_may_df)
ada_may = ada_may.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

ada_june_df = Path('ada_june.csv')
ada_june = pd.read_csv(ada_june_df)
ada_june = ada_june.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

ada_july_df = Path('ada_july.csv')
ada_july = pd.read_csv(ada_july_df)
ada_july = ada_july.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

ada_sent = pd.concat([ada_march, ada_april, ada_may, ada_june, ada_july], axis=1, keys=["March_ADA", "April_ADA", "May_ADA", "June_ADA", "July_ADA"])
ada_sent.head()

filepath = Path('ada_sent.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
ada_sent.to_csv(filepath)

# %%
sol_march_df = Path('sol_march.csv')
sol_march = pd.read_csv(sol_march_df)
sol_march = sol_march.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

sol_april_df = Path('sol_april.csv')
sol_april = pd.read_csv(sol_april_df)
sol_april = sol_april.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

sol_may_df = Path('sol_may.csv')
sol_may = pd.read_csv(sol_may_df)
sol_may = sol_may.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

sol_june_df = Path('sol_june.csv')
sol_june = pd.read_csv(sol_june_df)
sol_june = sol_june.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

sol_july_df = Path('sol_july.csv')
sol_july = pd.read_csv(sol_july_df)
sol_july = sol_july.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

sol_sent = pd.concat([sol_march, sol_april, sol_may, sol_june, sol_july], axis=1, keys=["March_SOL", "April_SOL", "May_SOL", "June_SOL", "July_SOL"])
sol_sent.head()

filepath = Path('sol_sent.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
sol_sent.to_csv(filepath)

# %%
luna_march_df = Path('luna_march.csv')
luna_march = pd.read_csv(luna_march_df)
luna_march = luna_march.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

luna_april_df = Path('luna_april.csv')
luna_april = pd.read_csv(luna_april_df)
luna_april = luna_april.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

luna_may_df = Path('luna_may.csv')
luna_may = pd.read_csv(sol_may_df)
luna_may = luna_may.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

luna_june_df = Path('luna_june.csv')
luna_june = pd.read_csv(luna_june_df)
luna_june = luna_june.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

luna_july_df = Path('luna_july.csv')
luna_july = pd.read_csv(luna_july_df)
luna_july = luna_july.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

luna_sent = pd.concat([luna_march, luna_april, luna_may, luna_june, luna_july], axis=1, keys=["March_LUNA", "April_LUNA", "May_LUNA", "June_LUNA", "July_LUNA"])
luna_sent.head()

filepath = Path('luna_sent.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
luna_sent.to_csv(filepath)

# %%
bnb_march_df = Path('bnb_march.csv')
bnb_march = pd.read_csv(bnb_march_df)
bnb_march = bnb_march.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

bnb_april_df = Path('bnb_april.csv')
bnb_april = pd.read_csv(bnb_april_df)
bnb_april = bnb_april.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

bnb_may_df = Path('bnb_may.csv')
bnb_may = pd.read_csv(bnb_may_df)
bnb_may = bnb_may.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

bnb_june_df = Path('bnb_june.csv')
bnb_june = pd.read_csv(bnb_june_df)
bnb_june = bnb_june.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

bnb_july_df = Path('bnb_july.csv')
bnb_july = pd.read_csv(bnb_july_df)
bnb_july = bnb_july.drop(columns=["Unnamed: 0", "url", "authors", "banner_image", "source", "category_within_source", "title", "summary", "source_domain", "topics", "ticker_sentiment"])

bnb_sent = pd.concat([bnb_march, bnb_april, bnb_may, bnb_june, bnb_july], axis=1, keys=["March_BNB", "April_BNB", "May_BNB", "June_BNB", "July_BNB"])
bnb_sent.head()

filepath = Path('bnb_sent.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
bnb_sent.to_csv(filepath)

# %%
#pd.concat([df1.set_index('A'),df2.set_index('A')], axis=1, join='inner')
tots = pd.concat([btc_sent, eth_sent,luna_sent, sol_sent, ada_sent, bnb_sent], axis=1, join='outer', keys=['BTC','ETH','LUNA','SOL','ADA','BNB'])
tots.head()
# Out:
#                    BTC                                                  \
#              March_BTC
#         time_published overall_sentiment_score overall_sentiment_label
# 0  2022-03-01 12:58:36               -0.138797                 Neutral
# 1  2022-03-02 02:32:56               -0.031243                 Neutral
# 2  2022-03-02 08:00:00               -0.174572        Somewhat-Bearish
# 3  2022-03-02 10:00:25               -0.036470                 Neutral
# 4  2022-03-02 11:00:26                0.034280                 Neutral
#
#                                                                         \
#              April_BTC
#         time_published overall_sentiment_score overall_sentiment_label
# 0  2022-04-01 00:08:13               -0.105202                 Neutral
# 1  2022-04-01 01:15:18               -0.059152                 Neutral
# 2  2022-04-01 01:26:14               -0.047444                 Neutral
# ...

# %%
filepath = Path('tots.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
tots.to_csv(filepath)
